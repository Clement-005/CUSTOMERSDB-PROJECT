# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers=pd.read_csv("customers.csv")

# %%
customers.head(20)
customers.shape
# Out:
# (777, 10)

# %%
customers.dtypes
# Out:
# Customer ID        int64
# Name              object
# Email             object
# Phone Number      object
# Street Address    object
# City              object
# State             object
# Zip Code           int64
# Sales Rep         object
# Subscription      object
# dtype: object

# %%
customers.isnull().any()
# Out:
# Customer ID       False
# Name              False
# Email             False
# Phone Number       True
# Street Address     True
# City              False
# State             False
# Zip Code          False
# Sales Rep         False
# Subscription      False
# dtype: bool

# %%
customers.isnull().sum()
# Out:
# Customer ID       0
# Name              0
# Email             0
# Phone Number      2
# Street Address    2
# City              0
# State             0
# Zip Code          0
# Sales Rep         0
# Subscription      0
# dtype: int64

# %%
customers.fillna("unknown", inplace=True)
print(customers.head())
# Out:
#    Customer ID              Name                           Email  \
# 0            1  Kathryn Williams  kathrynwilliams@samplemail.com
# 1            2      Maxwell Meza      maxwellmeza@samplemail.com
# 2            3    Jamie Crawford    jamiecrawford@samplemail.com
# 3            4   Raven Hernandez   ravenhernandez@samplemail.com
# 4            5      Robert Brown      robertbrown@samplemail.com
#
#      Phone Number               Street Address             City  \
# 0  (550) 269-8345             6122 Debra Court     Stewartville
# 1  (712) 706-8059             740 Bean Station    Lake Aprilton
# 2  (278) 738-1122  65114 Tracy Track Suite 604  South Sarahbury
# 3  (376) 539-3142       45083 Cunningham Drive        Jasonstad
# 4  (368) 263-0915                3965 Jay Ford          New Ann
#
#            State  Zip Code         Sales Rep Subscription
# 0         Hawaii     55169  Patricia Escobar     Standard
# 1          Maine      9073     Thomas Murray     Standard
# ...

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     777 non-null    int64
#  1   Name            777 non-null    object
#  2   Email           777 non-null    object
#  3   Phone Number    777 non-null    object
#  4   Street Address  777 non-null    object
#  5   City            777 non-null    object
#  6   State           777 non-null    object
#  7   Zip Code        777 non-null    int64
#  8   Sales Rep       777 non-null    object
#  9   Subscription    777 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 60.8+ KB

# %%
import mysql.connector

# %%
from sqlalchemy import create_engine

# %%
conn = mysql.connector.connect( 
    host="localhost",
    user="root", 
    password="@Cabenla_13", 
    database="CUSTOMERSDB"
) 
cursor = conn.cursor()

# %%
engine = create_engine("mysql+mysqlconnector://root:%40Cabenla_13@localhost/CUSTOMERSDB")

# %%
customers.columns = ['customer_id','name','email','phone_number','street_address','city','state','zip_code','sales_rep','subscription']
try:
    customers.to_sql(
        name='customers', 
        con=engine, 
        if_exists='append', 
        index=False          
    )
    print("Data uploaded successfully without changing the table design!")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Data uploaded successfully without changing the table design!

# %%
print(f"Rows to upload: {len(customers)}")
print(customers.head())
# Out:
# Rows to upload: 777
#    customer_id              name                           email  \
# 0            1  Kathryn Williams  kathrynwilliams@samplemail.com
# 1            2      Maxwell Meza      maxwellmeza@samplemail.com
# 2            3    Jamie Crawford    jamiecrawford@samplemail.com
# 3            4   Raven Hernandez   ravenhernandez@samplemail.com
# 4            5      Robert Brown      robertbrown@samplemail.com
#
#      phone_number               street_address             city  \
# 0  (550) 269-8345             6122 Debra Court     Stewartville
# 1  (712) 706-8059             740 Bean Station    Lake Aprilton
# 2  (278) 738-1122  65114 Tracy Track Suite 604  South Sarahbury
# 3  (376) 539-3142       45083 Cunningham Drive        Jasonstad
# 4  (368) 263-0915                3965 Jay Ford          New Ann
#
#            state  zip_code         sales_rep subscription
# 0         Hawaii     55169  Patricia Escobar     Standard
# ...

# %%
customers.to_sql(
    name='customers',
    con=engine,
    if_exists='replace',  
    index=False,
    chunksize=1000   
)
# Out:
# 777

# %%
Connect to your database
# (Replace with your actual credentials)
engine = create_engine('mysql+pymysql://user:password@localhost/db_name')

# 2. Prepare your DataFrame
# IMPORTANT: Your DataFrame column names MUST match your MySQL column names exactly (case-sensitive)
# If your SQL column is 'UserID' but Python is 'user_id', it will fail.
customers.columns = ['id', 'name', 'email', 'created_at'] # Example renaming

# 3. Upload using 'append'
try:
    customers.to_sql(
        name='customers', 
        con=engine, 
        if_exists='append',  # <--- THIS IS THE KEY: It won't change your design
        index=False          # <--- Prevents Python from adding an 'index' column
    )
    print("Data uploaded successfully without changing the table design!")
except Exception as e:
    print(f"Error: {e}")
# Out:
#   Cell In[17], line 1
#     Connect to your database
#             ^
# SyntaxError: invalid syntax

# %%
qqmajsimtozskggk

# %%
import smtplib
import ssl
from email.message import EmailMessage

# %%
msg = EmailMessage()
msg["Subject"] = "Happy Valentines Day"
msg["From"] = "clementamenlemah@gmail.com"
msg["To"] = "clementamenlemah@gmail.com"
msg.set_content("Hello Clement, please pass by our mart for your valentine's day gift.")

# 2️⃣ Connect to SMTP server
smtp_server = "smtp.gmail.com"
port = 587  # TLS port

context = ssl.create_default_context()

with smtplib.SMTP(smtp_server, port) as server:
    server.starttls(context=context)   # Secure connection
    server.login("clementamenlemah@gmail.com", "qqmajsimtozskggk")  # Login
    server.send_message(msg)  # 3️⃣ Send email

print("Email sent successfully!")
# Out:
# Email sent successfully!
